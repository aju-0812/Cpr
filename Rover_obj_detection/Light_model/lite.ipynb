# %% [markdown]
# Use colab if there is no cmake

# %%
# !pip install ultralytics
from ultralytics import YOLO

# Load your uploaded model
model = YOLO("best.pt")

# Export to TFLite with INT8 Quantization (Compression)
model.export(format="tflite", int8=True)
